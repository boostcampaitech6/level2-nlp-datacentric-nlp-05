# %% [markdown]
# # 데이터 증강
# 아래의 방법들을 사용해 데이터 증강을 수행
# - Round Trip Translation
# - koEDA

# %%
import pandas as pd

# %%
train_data = pd.read_csv("../../data/train.csv")

# %% [markdown]
# ### Round Trip Translation
# kortt 라이브러리를 사용해 RTT를 수행했으며, papago로 번역하기에 naver CLIENT_ID와 SECRET_ID를 발급해야 한다.

# %%
from kortt import Generator

generator = Generator(mode="papago", client_id="BGj2lvXHjZhEVS0Xmb61", secret_id="ZOFUc7NxY5")

result = generator.generate("美 우방 안심시키기…폼페이오 예루살렘서 네타냐후와 회담")
print(result)
# Out:
# 미국의 우정을 풀어주는...폼페이오, 예루살렘서 네타냐후와 회담

# %% [markdown]
# train data 10개만 증강

# %%
i = 0
for idx, data in enumerate(train_data["text"]):
    translated_data = generator.generate(data)
    train_data.loc[len(train_data)+1] = [train_data.iloc[idx, 0], translated_data, train_data.iloc[idx, 2], train_data.iloc[idx, 3], train_data.iloc[idx, 4]]
    i += 1
    if i == 10:
        break

# %%
train_data[7000:]
# Out:
#                        ID                                text  target
# 7001  ynat-v1_train_00000           개포2단지 분양 앞두고 개포지구 재건축 불붙어       1  \
# 7002  ynat-v1_train_00001          삼성전자 'KBIS 2018 셰프컬렉션' 선보여       0
# 7003  ynat-v1_train_00002    LG G6를 사면 BO 이어폰은 5,000원 밖에 안 된다       0
# 7004  ynat-v1_train_00003           새로운 블록체인 혁명 2030과 남성의 외로움       3
# 7005  ynat-v1_train_00004  이스라엘 정보당국은 테러 혐의로 팔레스타인인 50명을 체포했다       4
# 7006  ynat-v1_train_00005   배구연맹 이영일구 순천 KOVO 커 부녕 에이전시 입찰 공고       5
# 7007  ynat-v1_train_00006    콜마비앤에이치 지난해 영업이익 352억 원...54.5%↑       1
# 7008  ynat-v1_train_00007      SOL 1조2000억원 경유·납품·항공유 공급계약 체결       1
# 7009  ynat-v1_train_00008          카카오와 삼성화재, 디지털 손해보험사 설립 추진       1
# 7010  ynat-v1_train_00009                     김병준, 나경원 비대위 참석       6
#
#                                                     url                  date
# 7001  https://news.naver.com/main/read.nhn?mode=LS2D...  2016.03.16. 오전 11:37
# 7002  https://news.naver.com/main/read.nhn?mode=LS2D...   2018.01.10. 오전 8:33
# 7003  https://news.naver.com/main/read.nhn?mode=LS2D...  2017.04.30. 오전 10:00
# 7004  https://news.naver.com/main/read.nhn?mode=LS2D...  2019.06.13. 오전 11:49
# 7005  https://news.naver.com/main/read.nhn?mode=LS2D...  2019.12.18. 오후 11:15
# 7006  https://sports.news.naver.com/news.nhn?oid=001...      2019.07.10 16:47
# 7007  https://news.naver.com/main/read.nhn?mode=LS2D...   2016.01.18. 오후 4:45
# 7008  https://news.naver.com/main/read.nhn?mode=LS2D...  2017.01.05. 오전 10:21
# 7009  https://news.naver.com/main/read.nhn?mode=LS2D...  2019.10.23. 오전 10:49
# 7010  https://news.naver.com/main/read.nhn?mode=LS2D...   2019.02.08. 오후 6:32

# %% [markdown]
# papago를 사용해 RTT를 수행하니 생성되는 text의 quality가 좋았지만, papago의 일일사용량이 제한되어있음

# %% [markdown]
# ### koEDA
# koeda를 사용해 데이터를 증강했으며, 라이브러리의 기능은 아래와 같음
# - AEasierDataAugmentation (AEDA) : 문장 안에 특수기호들을 랜덤으로 삽입
# - RandomDeletion (RD) : p의 확률값을 가지고 문장 내의 각 단어들을 제거
# - RandomInsertion (RI) : 하나의 단어를 선택하고 그 단어의 유의어를 문장내의 임의의 위치에 삽입. n번 시행
# - SynonymReplacement (SR) : stop words가 아닌 단어들 중에서 랜덤으로 선택해서 유의어로 교체
# - RandomSwap (RS) : 랜덤으로 2개의 단어를 선택해 위치를 바꾸며 n번 시행

# %%
from koeda import EDA, RD, RI, SR, RS 
import random

# %%
# 각 args들은 문장 내에서 실행할 비율을 입력
eda = EDA(
    morpheme_analyzer="Okt", alpha_sr=0.1, alpha_ri=0.1, alpha_rs=0.1, prob_rd=0.1
)

random_delete = RD()    # 문장 내의 각 단어들을 무작위로 제거
random_insert = RI()    # 하나의 단어를 선택하고 그 단어의 유의어를 문장내의 임의의 위치에 삽입
random_swap = RS()      # 랜덤으로 2개의 단어를 선택해 위치를 바꿈
synonym_replace = SR()  # stop words가 아닌 단어들 중에서 랜덤으로 선택해 유의어로 교체

# %%
i = 0
for idx, data in enumerate(train_data["text"]):
    r = random.uniform(0,1)
    print("r:",r)
        
    if r < 0.25:
        augmented_data = random_delete(data, p=0.2)
    elif r >= 0.25 and r < 0.50:
        augmented_data = random_insert(data, p=0.2)
    elif r >= 0.50 and r < 0.75:
        augmented_data = random_swap(data, p=0.2)
    else:
        augmented_data = synonym_replace(data, p=0.2)
        
    train_data.loc[len(train_data)] = [train_data.iloc[idx, 0], augmented_data, train_data.iloc[idx, 2], train_data.iloc[idx, 3], train_data.iloc[idx, 4]]
    i += 1
    if i == 10:
        break
# Out:
# r: 0.7006212187638886
# r: 0.6270917161745785
# r: 0.6648589635044229
# r: 0.8475672457246514
# r: 0.3053737088841857
# r: 0.17840940435534758
# r: 0.6091560776188113
# r: 0.8909329594187545
# r: 0.8845267811612151
# r: 0.4901557267060329

# %%
train_data[7000:]
# Out:
#                        ID                                   text  target
# 7000  ynat-v1_train_00000              개포 앞두고 분양 단지 개포지구2재건축 불붙어       1  \
# 7001  ynat-v1_train_00001               삼성전자 KBIS컬렉션2018서 셰프 선보여       0
# 7002  ynat-v1_train_00002                LG 이6 사면 BO 이어폰G 단돈 5천원       0
# 7003  ynat-v1_train_00003                 신간 블록체인혁명 2030·동정의 고독사       3
# 7004  ynat-v1_train_00004  이스라엘 정보당국 팔레스타인인 50명 테러 경찰국 혐의로 소식 체포       4
# 7005  ynat-v1_train_00005           배구연맹 영일구 KOVO커 부녕 대행업체 입찰 공고       5
# 7006  ynat-v1_train_00006            콜마비앤에이치…작년 익영업 352억원 54.5%↑       1
# 7007  ynat-v1_train_00007             SOil 1조2천억원 경유·납사·항부품 공급계약       1
# 7008  ynat-v1_train_00008               카카오·삼성화재 디지털 상실보험사 설립 추진       1
# 7009  ynat-v1_train_00009               긴급비상대책위 참석하는 김병준과 출석 나경원       6
#
#                                                     url                  date
# 7000  https://news.naver.com/main/read.nhn?mode=LS2D...  2016.03.16. 오전 11:37
# 7001  https://news.naver.com/main/read.nhn?mode=LS2D...   2018.01.10. 오전 8:33
# 7002  https://news.naver.com/main/read.nhn?mode=LS2D...  2017.04.30. 오전 10:00
# 7003  https://news.naver.com/main/read.nhn?mode=LS2D...  2019.06.13. 오전 11:49
# 7004  https://news.naver.com/main/read.nhn?mode=LS2D...  2019.12.18. 오후 11:15
# 7005  https://sports.news.naver.com/news.nhn?oid=001...      2019.07.10 16:47
# 7006  https://news.naver.com/main/read.nhn?mode=LS2D...   2016.01.18. 오후 4:45
# 7007  https://news.naver.com/main/read.nhn?mode=LS2D...  2017.01.05. 오전 10:21
# 7008  https://news.naver.com/main/read.nhn?mode=LS2D...  2019.10.23. 오전 10:49
# 7009  https://news.naver.com/main/read.nhn?mode=LS2D...   2019.02.08. 오후 6:32

# %%
train_data["text"][7000:]
# Out:
# 7001            개포2단지불분양 앞두고 개포 지구재건축 붙어
# 7002           삼성2018 KBIS 전자서 셰프컬렉션 선보여
# 7003              LG G6 사면 BO 이 단돈이어폰5천원
# 7004              신간 블록체인혁명 2030고독사남자의 ·
# 7005        명당국 팔레스타인인 50정보 테러이스라엘혐의로 체포
# 7006    배구KOVO 이영일구 순천 연맹커 부녕 대행업체 공고 입찰
# 7007          마비…에이치 작년 영업익콜352억원앤54.5%↑
# 7008          SOil 1조2천억원 경유·납사공급·공유 항계약
# 7009            디지털·삼성화재 카카오 손해보험사 설립 추진
# 7010                 긴급비상대책위 참석하는나경원김병준과
# Name: text, dtype: object

# %%
# 테스트
import sys
sys.path.append("/data/ephemeral/code/")
from preprocessing import data_augmentation

train_data = pd.read_csv("../../data/train.csv")

train_data = data_augmentation(train_data)

# %%
train_data[7000:]
# Out:
#                         ID                                 text  target
# 7000   ynat-v1_train_00000               개포2단지 앞두고 개포지구 재건축 불붙어       1  \
# 7001   ynat-v1_train_00000         개포2단지 분양 앞두고 개포 병 지구 재건축 불붙어       1
# 7002   ynat-v1_train_00000             개포2단지 분양불앞두고 개포지구 재건축 붙어       1
# 7003   ynat-v1_train_00000            개포2단지 분양 앞두고 개포지대 재건축 불붙어       1
# 7004   ynat-v1_train_00001              전자 KBIS 2018서 셰프컬렉션 선보여       0
# ...                    ...                                  ...     ...
# 34995  ynat-v1_train_06998      문 대통령 1987 관람…깜짝 방문에 객석 환호·박수복합       6
# 34996  ynat-v1_train_06999          120년 전 대한제국으로…가을 정동에서 시간 여행       3
# 34997  ynat-v1_train_06999  120년 경각 전 대한제국으로…가을밤 정동에서 시간 여행 떠나다       3
# 34998  ynat-v1_train_06999     120년 전 대한제국으로…가을밤 떠나다에서 시간 여행 정동       3
# 34999  ynat-v1_train_06999    120년 전 대한제국으로…가을야밤 정동에서 시간 여행 떠나다       3
#
#                                                      url                  date
# 7000   https://news.naver.com/main/read.nhn?mode=LS2D...  2016.03.16. 오전 11:37
# 7001   https://news.naver.com/main/read.nhn?mode=LS2D...  2016.03.16. 오전 11:37
# 7002   https://news.naver.com/main/read.nhn?mode=LS2D...  2016.03.16. 오전 11:37
# 7003   https://news.naver.com/main/read.nhn?mode=LS2D...  2016.03.16. 오전 11:37
# 7004   https://news.naver.com/main/read.nhn?mode=LS2D...   2018.01.10. 오전 8:33
# ...                                                  ...                   ...
# 34995  https://news.naver.com/main/read.nhn?mode=LS2D...   2018.01.07. 오후 5:23
# 34996  https://news.naver.com/main/read.nhn?mode=LS2D...   2016.10.28. 오후 8:13
# 34997  https://news.naver.com/main/read.nhn?mode=LS2D...   2016.10.28. 오후 8:13
# 34998  https://news.naver.com/main/read.nhn?mode=LS2D...   2016.10.28. 오후 8:13
# 34999  https://news.naver.com/main/read.nhn?mode=LS2D...   2016.10.28. 오후 8:13
#
# [28000 rows x 5 columns]
